# %% [markdown]
# <a href="https://colab.research.google.com/github/Snehamn24/RAG-Phoria/blob/main/RAG_Phoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install the packages
# !pip install -U langchain langchain-community faiss-cpu sentence-transformers

# %%
# !pip install pypdf

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("/content/Employee-Handbook.pdf")
documents = loader.load()

print("Documents loaded:", len(documents))

# %%
documents[0]

# %% [markdown]
# # Splitting (Chunking)

# %%
# !pip install langchain-text-splitters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

docs = splitter.split_documents(documents)

print("Total chunks:", len(docs))

# %% [markdown]
# # Create Embeddings

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings()

print("Embeddings model loaded")

# %% [markdown]
# # Store in Vector Database (FAISS)

# %%
from langchain_community.vectorstores import FAISS

db = FAISS.from_documents(docs, embeddings)

print("Vector DB created successfully")

# %% [markdown]
# # Retrieval (Getting relevant data)

# %%
query = "What is employee health policy?"

retriever = db.as_retriever()

results = retriever.invoke(query)

for i,r in enumerate(results):
  print(f"\n Result {i+1}:\n")
  print(r.page_content)

# %% [markdown]
# # query = "What is leave policy?"
# # query = "What is discrimination policy?"
# # query = "What happens in long term illness?"

# %%
query = "What is leave policy?"

retriever = db.as_retriever()

results = retriever.invoke(query)

for i,r in enumerate(results):
  print(f"\n Result {i+1}:\n")
  print(r.page_content)

# %%
query = "What is discrimination policy?"

retriever = db.as_retriever()

results = retriever.invoke(query)

for i,r in enumerate(results):
  print(f"\n Result {i+1}:\n")
  print(r.page_content)

# %%
query = "What happens in long term illness?"

retriever = db.as_retriever()

results = retriever.invoke(query)

for i,r in enumerate(results):
  print(f"\n Result {i+1}:\n")
  print(r.page_content)
